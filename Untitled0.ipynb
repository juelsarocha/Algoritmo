# %% [markdown]
# <a href="https://colab.research.google.com/github/juelsarocha/Algoritmo/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculadora (numero1, numero2, operacao) :
  if (operacao == 1) :
    return numero1 + numero2
  elif (operacao == 2) :
    return numero1 - numero2
  elif (operacao == 3) :
    return numero1 * numero2
  elif (operacao == 4) :
    return numero1 / numero2
  else :
    return 0

excutar = True

while ( executar == True) :
  print("Escolha uma operação")
  print("1: Soma 2: Subtração 3: Multiplicação 4: Divisão" 0 :
  operacao= int(input())
  if(operacao < 0) or (operacao > 4) :
        print("Essa opção não existe")
  elif(operacao == 0) :
        executar = False
  else :
        print("Inserir o primeiro número da operação :")
        numero1 = int (input())
        print("Inserir o segundo número da operação :")
        numero2 = int (input())
        resultado = calculadora (numero1, numero2, operacao)
        print("Qual é o resultado? :" resultado)
